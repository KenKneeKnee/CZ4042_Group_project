# %% [markdown]
# # CZ4042 Group Project - Data Analysis
# Note: DO NOT EDIT THIS FILE UNLESS COLLABORATING

# %%
from .scripts import PATH_TO_DATA
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# /Users/peanutsee/Desktop/Year 4 Sem 1/CZ4042 - Neural Network & Deep Learning/Group Project/notebooks/main.ipynb Cell 2 line 1
# ----> <a href='vscode-notebook-cell:/Users/peanutsee/Desktop/Year%204%20Sem%201/CZ4042%20-%20Neural%20Network%20%26%20Deep%20Learning/Group%20Project/notebooks/main.ipynb#W1sZmlsZQ%3D%3D?line=0'>1</a> from ..scripts import PATH_TO_DATA
#
# ImportError: attempted relative import with no known parent package
