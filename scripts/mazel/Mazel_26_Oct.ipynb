# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sb
# %matplotlib inline

import sys
import os
import pytreebank
import nltk

from nltk.sentiment.vader import SentimentIntensityAnalyzer
from textblob import TextBlob

# SCRIPT_DIR = os.path.dirname(os.path.abspath('../scripts/scripts/'))
# sys.path.append(os.path.dirname(SCRIPT_DIR))

# from scripts.constants import PATH_TO_DATA, DATA_FILE_NAME

# %%
data = pytreebank.load_sst("data/SST2-Data/SST2-Data/trainDevTestTrees_PTB/trees/")

# %%
out_path = os.path.join("data/sst_{}.txt")

# %%
for cat in ['train','test','dev']:
    with open(out_path.format(cat),"w") as file:
        for item in data[cat]:
            file.write("__label__{}\t{}\n".format(
                item.to_labeled_lines()[0][0] +1,
                item.to_labeled_lines()[0][1]
            ))
    
    print("done with {}".format(file))
# Out:
# done with <_io.TextIOWrapper name='data/sst_train.txt' mode='w' encoding='UTF-8'>
# done with <_io.TextIOWrapper name='data/sst_test.txt' mode='w' encoding='UTF-8'>
# done with <_io.TextIOWrapper name='data/sst_dev.txt' mode='w' encoding='UTF-8'>

# %%
df_train = pd.read_csv("data/sst_train.txt",sep="\t",header=None,names=['label','text'])
df_train['label'] = df_train['label'].str.replace("__label__","")
df_train['label'] = df_train['label'].astype(int).astype("category")

df_test = pd.read_csv("data/sst_test.txt",sep="\t",header=None,names=['label','text'])
df_test['label'] = df_test['label'].str.replace("__label__","")
df_test['label'] = df_test['label'].astype(int).astype("category")

# %%
df_train
# Out:
#      label                                               text
# 0        4  The Rock is destined to be the 21st Century 's...
# 1        5  The gorgeously elaborate continuation of `` Th...
# 2        4  Singer/composer Bryan Adams contributes a slew...
# 3        3  You 'd think by now America would have had eno...
# 4        4               Yet the act is still charming here .
# ...    ...                                                ...
# 8539     1                                    A real snooze .
# 8540     2                                     No surprises .
# 8541     4  We 've seen the hippie-turned-yuppie plot befo...
# 8542     1  Her fans walked out muttering words like `` ho...
# 8543     2                                In this case zero .
#
# [8544 rows x 2 columns]

# %%
df_test
# Out:
#      label                                               text
# 0        3                     Effective but too-tepid biopic
# 1        4  If you sometimes like to go to the movies to h...
# 2        5  Emerges as something rare , an issue movie tha...
# 3        3  The film provides some great insight into the ...
# 4        5  Offers that rare combination of entertainment ...
# ...    ...                                                ...
# 2205     4                   An imaginative comedy/thriller .
# 2206     5                      ( A ) rare , beautiful film .
# 2207     5                 ( An ) hilarious romantic comedy .
# 2208     4                Never ( sinks ) into exploitation .
# 2209     1                        ( U ) nrelentingly stupid .
#
# [2210 rows x 2 columns]

# %%
import tensorflow as tf

# %%
embedding = "https://tfhub.dev/google/tf2-preview/gnews-swivel-20dim/1"

# %%
import tensorflow_hub as hub
hub_layer = hub.KerasLayer(embedding, input_shape=[], dtype=tf.string, trainable=True)

# %%
hub_layer(df_train['text'][:10])
# Out:
# <tf.Tensor: shape=(10, 20), dtype=float32, numpy=
# array([[-0.17569035, -1.5676816 ,  0.8543786 , -0.5981151 , -1.2136153 ,
#         -0.01878982, -0.93524003,  0.23275281,  0.86174583, -0.01399387,
#         -1.3430052 ,  0.01748537,  0.18257691, -0.6852263 , -0.3805004 ,
#          0.15710342,  0.5811184 , -0.21914063, -0.13737044,  0.14191812],
#        [ 0.6795094 , -1.8112632 ,  2.1644907 , -0.98349875, -0.68851036,
#          0.9659213 , -0.631428  , -0.29652372,  2.2149396 , -1.2758911 ,
#         -0.27002046, -1.2925656 ,  0.16214599, -0.720647  ,  0.9443487 ,
#         -0.6805398 , -0.66745204,  0.89824945,  0.44124267, -0.76817054],
#        [ 0.9598038 , -1.6044576 ,  1.3790556 , -0.8387672 , -1.428725  ,
#         -0.54128206, -0.25341454, -0.5005333 ,  1.9526852 , -2.4039288 ,
#         -1.2525821 ,  0.46131307, -0.9943082 , -0.7892277 , -0.81704605,
#         -0.34173867,  0.6299704 , -0.61374605, -2.2921426 , -0.78803724],
#        [ 0.21703832, -0.21944825,  0.6043717 , -0.3707854 , -1.8639021 ,
#         -0.5166424 , -1.1120832 ,  0.19282213,  0.73490924,  0.7380398 ,
#          0.8119983 ,  0.09158022, -0.06612088,  0.4283329 , -1.2079954 ,
#          0.27865583,  0.63582665, -0.8680419 , -0.7400229 , -0.4970872 ],
#        [ 0.92281634, -0.7388269 ,  2.012464  , -0.51303387, -1.4556601 ,
#         -0.91292644, -0.49180976,  0.5406158 ,  1.2218294 , -0.15678573,
#         -0.1937445 , -0.04293763, -0.2148077 , -0.30848396, -1.2488295 ,
#          0.43697125,  0.7399821 ,  0.3266279 , -1.2398485 , -0.22983949],
#        [ 1.2610178 , -0.6678109 ,  1.6681988 ,  0.23630485, -0.5843611 ,
#         -0.6558323 ,  0.35880372,  0.45198604,  1.4406995 , -0.658179  ,
#         -0.72664183, -0.03042554, -0.8761636 ,  0.27794555, -0.81768376,
#         -0.8878179 ,  1.0579501 , -0.3276312 , -1.5069162 , -0.895369  ],
#        [ 1.7488297 ,  0.93796027,  1.2906867 , -0.30557832, -0.01254675,
#         -0.88734174, -0.25059047, -0.29902712,  0.5299254 , -2.5570936 ,
#         -0.11448038,  0.18464902, -1.0467572 , -0.08663079, -0.98608166,
#          0.34761396, -0.15524451, -0.38454583, -1.874766  , -0.83630604],
#        [ 0.9881321 ,  0.26457456,  1.0903616 , -0.7423688 , -0.47952145,
#         -0.45329475, -0.58957624,  0.20340158,  1.0901678 , -1.0175059 ,
#         -0.30743662, -0.07701533, -0.21423322, -0.23011439, -0.57662797,
#         -0.26282942,  0.32696003,  0.16621524, -0.85818547, -0.66188806],
#        [ 0.87630796, -0.95936173,  0.1860102 , -0.4950316 , -0.60984653,
#         -0.5290684 , -0.41939318, -0.61398625,  0.30359545, -0.7485689 ,
#          0.45465854,  0.80093795, -0.90842557, -0.48209816, -0.5485864 ,
#          0.13847087, -0.33463836, -0.10560045, -0.18005675, -0.30386788],
#        [-0.26383206,  0.4485748 ,  0.2869718 , -0.12952013, -0.12694457,
#         -0.794901  , -0.85688096, -0.9500395 , -0.75652874, -1.084858  ,
#          0.6173487 ,  0.4946552 ,  0.79096794,  0.1601301 ,  0.70203936,
#         -0.40108484,  0.6208519 , -0.8654393 ,  0.9173156 , -0.37453794]],
#       dtype=float32)>

# %%
model = tf.keras.Sequential()
model.add(hub_layer)
model.add(tf.keras.layers.Dense(16, activation='relu'))
model.add(tf.keras.layers.Dense(1, activation='softmax'))

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  keras_layer (KerasLayer)    (None, 20)                400020
#
#  dense_2 (Dense)             (None, 16)                336
#
#  dense_3 (Dense)             (None, 1)                 17
#
# =================================================================
# Total params: 400373 (1.53 MB)
# Trainable params: 400373 (1.53 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
model.compile(optimizer='adam', loss=tf.keras.losses.CategoricalCrossentropy(from_logits=True), metrics=['accuracy'])

# %%
train_dataset = tf.data.Dataset.from_tensor_slices((df_train['text'], df_train['label']))
test_dataset = tf.data.Dataset.from_tensor_slices((df_test['text'], df_test['label']))

# Batch the datasets
batch_size = 512
train_dataset = train_dataset.batch(batch_size)
test_dataset = test_dataset.batch(batch_size)

# %%
df_train
# Out:
#      label                                               text
# 0        4  The Rock is destined to be the 21st Century 's...
# 1        5  The gorgeously elaborate continuation of `` Th...
# 2        4  Singer/composer Bryan Adams contributes a slew...
# 3        3  You 'd think by now America would have had eno...
# 4        4               Yet the act is still charming here .
# ...    ...                                                ...
# 8539     1                                    A real snooze .
# 8540     2                                     No surprises .
# 8541     4  We 've seen the hippie-turned-yuppie plot befo...
# 8542     1  Her fans walked out muttering words like `` ho...
# 8543     2                                In this case zero .
#
# [8544 rows x 2 columns]

# %%
history = model.fit(
    train_dataset,      
    epochs=100,                                 
    validation_data=test_dataset, 
    verbose=1                                   
)
# Out:
# Epoch 1/100
# /Users/mazeltan/Desktop/CZ4042_Group_project/env/lib/python3.11/site-packages/tensorflow/python/util/dispatch.py:1260: SyntaxWarning: In loss categorical_crossentropy, expected y_pred.shape to be (batch_size, num_classes) with num_classes > 1. Received: y_pred.shape=(None, 1). Consider using 'binary_crossentropy' if you only have 2 classes.
#   return dispatch_target(*args, **kwargs)
# /Users/mazeltan/Desktop/CZ4042_Group_project/env/lib/python3.11/site-packages/keras/src/backend.py:5577: UserWarning: "`categorical_crossentropy` received `from_logits=True`, but the `output` argument was produced by a Softmax activation and thus does not represent logits. Was this intended?
#   output, from_logits = _get_logits(
# 17/17 [==============================] - 0s 8ms/step - loss: 0.0000e+00 - accuracy: 0.1278 - val_loss: 0.0000e+00 - val_accuracy: 0.1262
# Epoch 2/100
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0000e+00 - accuracy: 0.1278 - val_loss: 0.0000e+00 - val_accuracy: 0.1262
# Epoch 3/100
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0000e+00 - accuracy: 0.1278 - val_loss: 0.0000e+00 - val_accuracy: 0.1262
# Epoch 4/100
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0000e+00 - accuracy: 0.1278 - val_loss: 0.0000e+00 - val_accuracy: 0.1262
# Epoch 5/100
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0000e+00 - accuracy: 0.1278 - val_loss: 0.0000e+00 - val_accuracy: 0.1262
# Epoch 6/100
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0000e+00 - accuracy: 0.1278 - val_loss: 0.0000e+00 - val_accuracy: 0.1262
# Epoch 7/100
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0000e+00 - accuracy: 0.1278 - val_loss: 0.0000e+00 - val_accuracy: 0.1262
# Epoch 8/100
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0000e+00 - accuracy: 0.1278 - val_loss: 0.0000e+00 - val_accuracy: 0.1262
# Epoch 9/100
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0000e+00 - accuracy: 0.1278 - val_loss: 0.0000e+00 - val_accuracy: 0.1262
# Epoch 10/100
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0000e+00 - accuracy: 0.1278 - val_loss: 0.0000e+00 - val_accuracy: 0.1262
# Epoch 11/100
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0000e+00 - accuracy: 0.1278 - val_loss: 0.0000e+00 - val_accuracy: 0.1262
# Epoch 12/100
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0000e+00 - accuracy: 0.1278 - val_loss: 0.0000e+00 - val_accuracy: 0.1262
# Epoch 13/100
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0000e+00 - accuracy: 0.1278 - val_loss: 0.0000e+00 - val_accuracy: 0.1262
# Epoch 14/100
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0000e+00 - accuracy: 0.1278 - val_loss: 0.0000e+00 - val_accuracy: 0.1262
# Epoch 15/100
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0000e+00 - accuracy: 0.1278 - val_loss: 0.0000e+00 - val_accuracy: 0.1262
# Epoch 16/100
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0000e+00 - accuracy: 0.1278 - val_loss: 0.0000e+00 - val_accuracy: 0.1262
# Epoch 17/100
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0000e+00 - accuracy: 0.1278 - val_loss: 0.0000e+00 - val_accuracy: 0.1262
# Epoch 18/100
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0000e+00 - accuracy: 0.1278 - val_loss: 0.0000e+00 - val_accuracy: 0.1262
# Epoch 19/100
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0000e+00 - accuracy: 0.1278 - val_loss: 0.0000e+00 - val_accuracy: 0.1262
# Epoch 20/100
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0000e+00 - accuracy: 0.1278 - val_loss: 0.0000e+00 - val_accuracy: 0.1262
# Epoch 21/100
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0000e+00 - accuracy: 0.1278 - val_loss: 0.0000e+00 - val_accuracy: 0.1262
# Epoch 22/100
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0000e+00 - accuracy: 0.1278 - val_loss: 0.0000e+00 - val_accuracy: 0.1262
# Epoch 23/100
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0000e+00 - accuracy: 0.1278 - val_loss: 0.0000e+00 - val_accuracy: 0.1262
# Epoch 24/100
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0000e+00 - accuracy: 0.1278 - val_loss: 0.0000e+00 - val_accuracy: 0.1262
# Epoch 25/100
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0000e+00 - accuracy: 0.1278 - val_loss: 0.0000e+00 - val_accuracy: 0.1262
# Epoch 26/100
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0000e+00 - accuracy: 0.1278 - val_loss: 0.0000e+00 - val_accuracy: 0.1262
# Epoch 27/100
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0000e+00 - accuracy: 0.1278 - val_loss: 0.0000e+00 - val_accuracy: 0.1262
# Epoch 28/100
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0000e+00 - accuracy: 0.1278 - val_loss: 0.0000e+00 - val_accuracy: 0.1262
# Epoch 29/100
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0000e+00 - accuracy: 0.1278 - val_loss: 0.0000e+00 - val_accuracy: 0.1262
# Epoch 30/100
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0000e+00 - accuracy: 0.1278 - val_loss: 0.0000e+00 - val_accuracy: 0.1262
# Epoch 31/100
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0000e+00 - accuracy: 0.1278 - val_loss: 0.0000e+00 - val_accuracy: 0.1262
# Epoch 32/100
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0000e+00 - accuracy: 0.1278 - val_loss: 0.0000e+00 - val_accuracy: 0.1262
# Epoch 33/100
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0000e+00 - accuracy: 0.1278 - val_loss: 0.0000e+00 - val_accuracy: 0.1262
# Epoch 34/100
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0000e+00 - accuracy: 0.1278 - val_loss: 0.0000e+00 - val_accuracy: 0.1262
# Epoch 35/100
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0000e+00 - accuracy: 0.1278 - val_loss: 0.0000e+00 - val_accuracy: 0.1262
# Epoch 36/100
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0000e+00 - accuracy: 0.1278 - val_loss: 0.0000e+00 - val_accuracy: 0.1262
# Epoch 37/100
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0000e+00 - accuracy: 0.1278 - val_loss: 0.0000e+00 - val_accuracy: 0.1262
# Epoch 38/100
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0000e+00 - accuracy: 0.1278 - val_loss: 0.0000e+00 - val_accuracy: 0.1262
# Epoch 39/100
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0000e+00 - accuracy: 0.1278 - val_loss: 0.0000e+00 - val_accuracy: 0.1262
# Epoch 40/100
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0000e+00 - accuracy: 0.1278 - val_loss: 0.0000e+00 - val_accuracy: 0.1262
# Epoch 41/100
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0000e+00 - accuracy: 0.1278 - val_loss: 0.0000e+00 - val_accuracy: 0.1262
# Epoch 42/100
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0000e+00 - accuracy: 0.1278 - val_loss: 0.0000e+00 - val_accuracy: 0.1262
# Epoch 43/100
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0000e+00 - accuracy: 0.1278 - val_loss: 0.0000e+00 - val_accuracy: 0.1262
# Epoch 44/100
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0000e+00 - accuracy: 0.1278 - val_loss: 0.0000e+00 - val_accuracy: 0.1262
# Epoch 45/100
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0000e+00 - accuracy: 0.1278 - val_loss: 0.0000e+00 - val_accuracy: 0.1262
# Epoch 46/100
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0000e+00 - accuracy: 0.1278 - val_loss: 0.0000e+00 - val_accuracy: 0.1262
# Epoch 47/100
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0000e+00 - accuracy: 0.1278 - val_loss: 0.0000e+00 - val_accuracy: 0.1262
# Epoch 48/100
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0000e+00 - accuracy: 0.1278 - val_loss: 0.0000e+00 - val_accuracy: 0.1262
# Epoch 49/100
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0000e+00 - accuracy: 0.1278 - val_loss: 0.0000e+00 - val_accuracy: 0.1262
# Epoch 50/100
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0000e+00 - accuracy: 0.1278 - val_loss: 0.0000e+00 - val_accuracy: 0.1262
# Epoch 51/100
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0000e+00 - accuracy: 0.1278 - val_loss: 0.0000e+00 - val_accuracy: 0.1262
# Epoch 52/100
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0000e+00 - accuracy: 0.1278 - val_loss: 0.0000e+00 - val_accuracy: 0.1262
# Epoch 53/100
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0000e+00 - accuracy: 0.1278 - val_loss: 0.0000e+00 - val_accuracy: 0.1262
# Epoch 54/100
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0000e+00 - accuracy: 0.1278 - val_loss: 0.0000e+00 - val_accuracy: 0.1262
# Epoch 55/100
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0000e+00 - accuracy: 0.1278 - val_loss: 0.0000e+00 - val_accuracy: 0.1262
# Epoch 56/100
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0000e+00 - accuracy: 0.1278 - val_loss: 0.0000e+00 - val_accuracy: 0.1262
# Epoch 57/100
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0000e+00 - accuracy: 0.1278 - val_loss: 0.0000e+00 - val_accuracy: 0.1262
# Epoch 58/100
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0000e+00 - accuracy: 0.1278 - val_loss: 0.0000e+00 - val_accuracy: 0.1262
# Epoch 59/100
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0000e+00 - accuracy: 0.1278 - val_loss: 0.0000e+00 - val_accuracy: 0.1262
# Epoch 60/100
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0000e+00 - accuracy: 0.1278 - val_loss: 0.0000e+00 - val_accuracy: 0.1262
# Epoch 61/100
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0000e+00 - accuracy: 0.1278 - val_loss: 0.0000e+00 - val_accuracy: 0.1262
# Epoch 62/100
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0000e+00 - accuracy: 0.1278 - val_loss: 0.0000e+00 - val_accuracy: 0.1262
# Epoch 63/100
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0000e+00 - accuracy: 0.1278 - val_loss: 0.0000e+00 - val_accuracy: 0.1262
# Epoch 64/100
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0000e+00 - accuracy: 0.1278 - val_loss: 0.0000e+00 - val_accuracy: 0.1262
# Epoch 65/100
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0000e+00 - accuracy: 0.1278 - val_loss: 0.0000e+00 - val_accuracy: 0.1262
# Epoch 66/100
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0000e+00 - accuracy: 0.1278 - val_loss: 0.0000e+00 - val_accuracy: 0.1262
# Epoch 67/100
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0000e+00 - accuracy: 0.1278 - val_loss: 0.0000e+00 - val_accuracy: 0.1262
# Epoch 68/100
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0000e+00 - accuracy: 0.1278 - val_loss: 0.0000e+00 - val_accuracy: 0.1262
# Epoch 69/100
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0000e+00 - accuracy: 0.1278 - val_loss: 0.0000e+00 - val_accuracy: 0.1262
# Epoch 70/100
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0000e+00 - accuracy: 0.1278 - val_loss: 0.0000e+00 - val_accuracy: 0.1262
# Epoch 71/100
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0000e+00 - accuracy: 0.1278 - val_loss: 0.0000e+00 - val_accuracy: 0.1262
# Epoch 72/100
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0000e+00 - accuracy: 0.1278 - val_loss: 0.0000e+00 - val_accuracy: 0.1262
# Epoch 73/100
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0000e+00 - accuracy: 0.1278 - val_loss: 0.0000e+00 - val_accuracy: 0.1262
# Epoch 74/100
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0000e+00 - accuracy: 0.1278 - val_loss: 0.0000e+00 - val_accuracy: 0.1262
# Epoch 75/100
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0000e+00 - accuracy: 0.1278 - val_loss: 0.0000e+00 - val_accuracy: 0.1262
# Epoch 76/100
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0000e+00 - accuracy: 0.1278 - val_loss: 0.0000e+00 - val_accuracy: 0.1262
# Epoch 77/100
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0000e+00 - accuracy: 0.1278 - val_loss: 0.0000e+00 - val_accuracy: 0.1262
# Epoch 78/100
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0000e+00 - accuracy: 0.1278 - val_loss: 0.0000e+00 - val_accuracy: 0.1262
# Epoch 79/100
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0000e+00 - accuracy: 0.1278 - val_loss: 0.0000e+00 - val_accuracy: 0.1262
# Epoch 80/100
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0000e+00 - accuracy: 0.1278 - val_loss: 0.0000e+00 - val_accuracy: 0.1262
# Epoch 81/100
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0000e+00 - accuracy: 0.1278 - val_loss: 0.0000e+00 - val_accuracy: 0.1262
# Epoch 82/100
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0000e+00 - accuracy: 0.1278 - val_loss: 0.0000e+00 - val_accuracy: 0.1262
# Epoch 83/100
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0000e+00 - accuracy: 0.1278 - val_loss: 0.0000e+00 - val_accuracy: 0.1262
# Epoch 84/100
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0000e+00 - accuracy: 0.1278 - val_loss: 0.0000e+00 - val_accuracy: 0.1262
# Epoch 85/100
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0000e+00 - accuracy: 0.1278 - val_loss: 0.0000e+00 - val_accuracy: 0.1262
# Epoch 86/100
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0000e+00 - accuracy: 0.1278 - val_loss: 0.0000e+00 - val_accuracy: 0.1262
# Epoch 87/100
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0000e+00 - accuracy: 0.1278 - val_loss: 0.0000e+00 - val_accuracy: 0.1262
# Epoch 88/100
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0000e+00 - accuracy: 0.1278 - val_loss: 0.0000e+00 - val_accuracy: 0.1262
# Epoch 89/100
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0000e+00 - accuracy: 0.1278 - val_loss: 0.0000e+00 - val_accuracy: 0.1262
# Epoch 90/100
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0000e+00 - accuracy: 0.1278 - val_loss: 0.0000e+00 - val_accuracy: 0.1262
# Epoch 91/100
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0000e+00 - accuracy: 0.1278 - val_loss: 0.0000e+00 - val_accuracy: 0.1262
# Epoch 92/100
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0000e+00 - accuracy: 0.1278 - val_loss: 0.0000e+00 - val_accuracy: 0.1262
# Epoch 93/100
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0000e+00 - accuracy: 0.1278 - val_loss: 0.0000e+00 - val_accuracy: 0.1262
# Epoch 94/100
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0000e+00 - accuracy: 0.1278 - val_loss: 0.0000e+00 - val_accuracy: 0.1262
# Epoch 95/100
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0000e+00 - accuracy: 0.1278 - val_loss: 0.0000e+00 - val_accuracy: 0.1262
# Epoch 96/100
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0000e+00 - accuracy: 0.1278 - val_loss: 0.0000e+00 - val_accuracy: 0.1262
# Epoch 97/100
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0000e+00 - accuracy: 0.1278 - val_loss: 0.0000e+00 - val_accuracy: 0.1262
# Epoch 98/100
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0000e+00 - accuracy: 0.1278 - val_loss: 0.0000e+00 - val_accuracy: 0.1262
# Epoch 99/100
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0000e+00 - accuracy: 0.1278 - val_loss: 0.0000e+00 - val_accuracy: 0.1262
# Epoch 100/100
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0000e+00 - accuracy: 0.1278 - val_loss: 0.0000e+00 - val_accuracy: 0.1262

# %%
def train_input_fn():
    dataset = tf.data.Dataset.from_tensor_slices((df_train["text"], df_train["label"]))
    dataset = dataset.shuffle(buffer_size=len(df_train))
    dataset = dataset.batch(batch_size)
    return dataset

def test_input_fn():
    dataset = tf.data.Dataset.from_tensor_slices((df_test["text"], df_test["label"]))
    dataset = dataset.batch(batch_size)
    return dataset

embedded_text_feature_column = hub.text_embedding_column(
    key="text",
    module_spec="https://tfhub.dev/google/nnlm-en-dim128/1",
    trainable=True)

run_config = tf.estimator.RunConfig(keep_checkpoint_max=1)

estimator = tf.estimator.DNNClassifier(
    hidden_units=[250, 50],
    feature_columns=[embedded_text_feature_column],
    n_classes=5,
    config=run_config,
    optimizer=tf.compat.v1.train.AdagradOptimizer(learning_rate=0.003))

# Train the estimator
estimator.train(input_fn=train_input_fn, steps=10000)

# You can also evaluate the model on the test set:
results = estimator.evaluate(input_fn=test_input_fn)
print("Test set accuracy: {accuracy}".format(**results))
# Out:
# WARNING:tensorflow:From /var/folders/0s/6y_9xhvn7tx64mnfljyvm01m0000gn/T/ipykernel_64683/18763444.py:19: RunConfig.__init__ (from tensorflow_estimator.python.estimator.run_config) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.keras instead.
# WARNING:tensorflow:From /var/folders/0s/6y_9xhvn7tx64mnfljyvm01m0000gn/T/ipykernel_64683/18763444.py:19: RunConfig.__init__ (from tensorflow_estimator.python.estimator.run_config) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.keras instead.
# WARNING:tensorflow:From /var/folders/0s/6y_9xhvn7tx64mnfljyvm01m0000gn/T/ipykernel_64683/18763444.py:21: DNNClassifierV2.__init__ (from tensorflow_estimator.python.estimator.canned.dnn) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.keras instead.
# WARNING:tensorflow:From /var/folders/0s/6y_9xhvn7tx64mnfljyvm01m0000gn/T/ipykernel_64683/18763444.py:21: DNNClassifierV2.__init__ (from tensorflow_estimator.python.estimator.canned.dnn) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.keras instead.
# WARNING:tensorflow:From /Users/mazeltan/Desktop/CZ4042_Group_project/env/lib/python3.11/site-packages/tensorflow_estimator/python/estimator/head/head_utils.py:59: MultiClassHead.__init__ (from tensorflow_estimator.python.estimator.head.multi_class_head) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.keras instead.
# WARNING:tensorflow:From /Users/mazeltan/Desktop/CZ4042_Group_project/env/lib/python3.11/site-packages/tensorflow_estimator/python/estimator/head/head_utils.py:59: MultiClassHead.__init__ (from tensorflow_estimator.python.estimator.head.multi_class_head) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.keras instead.
# WARNING:tensorflow:From /Users/mazeltan/Desktop/CZ4042_Group_project/env/lib/python3.11/site-packages/tensorflow_estimator/python/estimator/canned/dnn.py:759: Estimator.__init__ (from tensorflow_estimator.python.estimator.estimator) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.keras instead.
# WARNING:tensorflow:From /Users/mazeltan/Desktop/CZ4042_Group_project/env/lib/python3.11/site-packages/tensorflow_estimator/python/estimator/canned/dnn.py:759: Estimator.__init__ (from tensorflow_estimator.python.estimator.estimator) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.keras instead.
# WARNING:tensorflow:Using temporary folder as model directory: /var/folders/0s/6y_9xhvn7tx64mnfljyvm01m0000gn/T/tmpfkk9dkqw
# WARNING:tensorflow:Using temporary folder as model directory: /var/folders/0s/6y_9xhvn7tx64mnfljyvm01m0000gn/T/tmpfkk9dkqw
# INFO:tensorflow:Using config: {'_model_dir': '/var/folders/0s/6y_9xhvn7tx64mnfljyvm01m0000gn/T/tmpfkk9dkqw', '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 600, '_session_config': allow_soft_placement: true
# graph_options {
#   rewrite_options {
#     meta_optimizer_iterations: ONE
#   }
# }
# , '_keep_checkpoint_max': 1, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 100, '_train_distribute': None, '_device_fn': None, '_protocol': None, '_eval_distribute': None, '_experimental_distribute': None, '_experimental_max_worker_delay_secs': None, '_session_creation_timeout_secs': 7200, '_checkpoint_save_graph_def': True, '_service': None, '_cluster_spec': ClusterSpec({}), '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 0, '_master': '', '_evaluation_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1}
# INFO:tensorflow:Using config: {'_model_dir': '/var/folders/0s/6y_9xhvn7tx64mnfljyvm01m0000gn/T/tmpfkk9dkqw', '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 600, '_session_config': allow_soft_placement: true
# graph_options {
#   rewrite_options {
#     meta_optimizer_iterations: ONE
#   }
# }
# , '_keep_checkpoint_max': 1, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 100, '_train_distribute': None, '_device_fn': None, '_protocol': None, '_eval_distribute': None, '_experimental_distribute': None, '_experimental_max_worker_delay_secs': None, '_session_creation_timeout_secs': 7200, '_checkpoint_save_graph_def': True, '_service': None, '_cluster_spec': ClusterSpec({}), '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 0, '_master': '', '_evaluation_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1}
# WARNING:tensorflow:From /Users/mazeltan/Desktop/CZ4042_Group_project/env/lib/python3.11/site-packages/tensorflow_estimator/python/estimator/estimator.py:385: StopAtStepHook.__init__ (from tensorflow.python.training.basic_session_run_hooks) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.keras instead.
# WARNING:tensorflow:From /Users/mazeltan/Desktop/CZ4042_Group_project/env/lib/python3.11/site-packages/tensorflow_estimator/python/estimator/estimator.py:385: StopAtStepHook.__init__ (from tensorflow.python.training.basic_session_run_hooks) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.keras instead.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Calling model_fn.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /Users/mazeltan/Desktop/CZ4042_Group_project/scripts/mazel/Mazel_26_Oct.ipynb Cell 18 line 2
#      <a href='vscode-notebook-cell:/Users/mazeltan/Desktop/CZ4042_Group_project/scripts/mazel/Mazel_26_Oct.ipynb#X45sZmlsZQ%3D%3D?line=20'>21</a> estimator = tf.estimator.DNNClassifier(
#      <a href='vscode-notebook-cell:/Users/mazeltan/Desktop/CZ4042_Group_project/scripts/mazel/Mazel_26_Oct.ipynb#X45sZmlsZQ%3D%3D?line=21'>22</a>     hidden_units=[250, 50],
#      <a href='vscode-notebook-cell:/Users/mazeltan/Desktop/CZ4042_Group_project/scripts/mazel/Mazel_26_Oct.ipynb#X45sZmlsZQ%3D%3D?line=22'>23</a>     feature_columns=[embedded_text_feature_column],
#      <a href='vscode-notebook-cell:/Users/mazeltan/Desktop/CZ4042_Group_project/scripts/mazel/Mazel_26_Oct.ipynb#X45sZmlsZQ%3D%3D?line=23'>24</a>     n_classes=5,
#      <a href='vscode-notebook-cell:/Users/mazeltan/Desktop/CZ4042_Group_project/scripts/mazel/Mazel_26_Oct.ipynb#X45sZmlsZQ%3D%3D?line=24'>25</a>     config=run_config,
#      <a href='vscode-notebook-cell:/Users/mazeltan/Desktop/CZ4042_Group_project/scripts/mazel/Mazel_26_Oct.ipynb#X45sZmlsZQ%3D%3D?line=25'>26</a>     optimizer=tf.compat.v1.train.AdagradOptimizer(learning_rate=0.003))
#      <a href='vscode-notebook-cell:/Users/mazeltan/Desktop/CZ4042_Group_project/scripts/mazel/Mazel_26_Oct.ipynb#X45sZmlsZQ%3D%3D?line=27'>28</a> # Train the estimator
# ---> <a href='vscode-notebook-cell:/Users/mazeltan/Desktop/CZ4042_Group_project/scripts/mazel/Mazel_26_Oct.ipynb#X45sZmlsZQ%3D%3D?line=28'>29</a> estimator.train(input_fn=train_input_fn, steps=10000)
#      <a href='vscode-notebook-cell:/Users/mazeltan/Desktop/CZ4042_Group_project/scripts/mazel/Mazel_26_Oct.ipynb#X45sZmlsZQ%3D%3D?line=30'>31</a> # You can also evaluate the model on the test set:
#      <a href='vscode-notebook-cell:/Users/mazeltan/Desktop/CZ4042_Group_project/scripts/mazel/Mazel_26_Oct.ipynb#X45sZmlsZQ%3D%3D?line=31'>32</a> results = estimator.evaluate(input_fn=test_input_fn)
#
# File ~/Desktop/CZ4042_Group_project/env/lib/python3.11/site-packages/tensorflow_estimator/python/estimator/estimator.py:360, in Estimator.train(self, input_fn, hooks, steps, max_steps, saving_listeners)
#     357 hooks.extend(self._convert_train_steps_to_hooks(steps, max_steps))
#     359 saving_listeners = _check_listeners_type(saving_listeners)
# --> 360 loss = self._train_model(input_fn, hooks, saving_listeners)
#     361 tf.compat.v1.logging.info('Loss for final step: %s.', loss)
#     362 return self
#
# File ~/Desktop/CZ4042_Group_project/env/lib/python3.11/site-packages/tensorflow_estimator/python/estimator/estimator.py:1188, in Estimator._train_model(self, input_fn, hooks, saving_listeners)
#    1186   return self._train_model_distributed(input_fn, hooks, saving_listeners)
#    1187 else:
# -> 1188   return self._train_model_default(input_fn, hooks, saving_listeners)
#
# File ~/Desktop/CZ4042_Group_project/env/lib/python3.11/site-packages/tensorflow_estimator/python/estimator/estimator.py:1216, in Estimator._train_model_default(self, input_fn, hooks, saving_listeners)
#    1213 features, labels, input_hooks = (
#    1214     self._get_features_and_labels_from_input_fn(input_fn, ModeKeys.TRAIN))
#    1215 worker_hooks.extend(input_hooks)
# -> 1216 estimator_spec = self._call_model_fn(features, labels, ModeKeys.TRAIN,
#    1217                                      self.config)
#    1218 global_step_tensor = tf.compat.v1.train.get_global_step(g)
#    1219 return self._train_with_estimator_spec(estimator_spec, worker_hooks,
#    1220                                        hooks, global_step_tensor,
#    1221                                        saving_listeners)
#
# File ~/Desktop/CZ4042_Group_project/env/lib/python3.11/site-packages/tensorflow_estimator/python/estimator/estimator.py:1176, in Estimator._call_model_fn(self, features, labels, mode, config)
#    1173   kwargs['config'] = config
#    1175 tf.compat.v1.logging.info('Calling model_fn.')
# -> 1176 model_fn_results = self._model_fn(features=features, **kwargs)
#    1177 tf.compat.v1.logging.info('Done calling model_fn.')
#    1179 if not isinstance(model_fn_results, model_fn_lib.EstimatorSpec):
#
# File ~/Desktop/CZ4042_Group_project/env/lib/python3.11/site-packages/tensorflow_estimator/python/estimator/canned/dnn.py:746, in DNNClassifierV2.__init__.<locals>._model_fn(features, labels, mode, config)
#     744 def _model_fn(features, labels, mode, config):
#     745   """Call the defined shared dnn_model_fn_v2."""
# --> 746   return dnn_model_fn_v2(
#     747       features=features,
#     748       labels=labels,
#     749       mode=mode,
#     750       head=head,
#     751       hidden_units=hidden_units,
#     752       feature_columns=tuple(feature_columns or []),
#     753       optimizer=optimizer,
#     754       activation_fn=activation_fn,
#     755       dropout=dropout,
#     756       config=config,
#     757       batch_norm=batch_norm)
#
# File ~/Desktop/CZ4042_Group_project/env/lib/python3.11/site-packages/tensorflow_estimator/python/estimator/canned/dnn.py:552, in dnn_model_fn_v2(features, labels, mode, head, hidden_units, feature_columns, optimizer, activation_fn, dropout, config, use_tpu, batch_norm)
#     507 def dnn_model_fn_v2(features,
#     508                     labels,
#     509                     mode,
#    (...)
#     517                     use_tpu=False,
#     518                     batch_norm=False):
#     519   """Deep Neural Net model_fn v2.
#     520
#     521   This function is different than _dnn_model_fn_v1 in the way it handles the
#    (...)
#     550     ValueError: If features has the wrong type.
#     551   """
# --> 552   _validate_features(features)
#     554   del config
#     556   logits, trainable_variables, update_ops = _dnn_model_fn_builder_v2(
#     557       units=head.logits_dimension,
#     558       hidden_units=hidden_units,
#    (...)
#     563       features=features,
#     564       mode=mode)
#
# File ~/Desktop/CZ4042_Group_project/env/lib/python3.11/site-packages/tensorflow_estimator/python/estimator/canned/dnn.py:364, in _validate_features(features)
#     362 def _validate_features(features):
#     363   if not isinstance(features, dict):
# --> 364     raise ValueError('features should be a dictionary of `Tensor`s. '
#     365                      'Given type: {}'.format(type(features)))
#
# ValueError: features should be a dictionary of `Tensor`s. Given type: <class 'tensorflow.python.framework.ops.SymbolicTensor'>

# %%
def textblob_score(sentence):
    return TextBlob(sentence).sentiment.polarity
df_test['tb_score'] =  df_test['text'].apply(textblob_score)
df_test
# Out:
#      label                                               text  tb_score
# 0        3                     Effective but too-tepid biopic     0.600
# 1        4  If you sometimes like to go to the movies to h...     0.500
# 2        5  Emerges as something rare , an issue movie tha...     0.450
# 3        3  The film provides some great insight into the ...     0.275
# 4        5  Offers that rare combination of entertainment ...     0.200
# ...    ...                                                ...       ...
# 2205     4                   An imaginative comedy/thriller .     0.600
# 2206     5                      ( A ) rare , beautiful film .     0.575
# 2207     5                 ( An ) hilarious romantic comedy .     0.250
# 2208     4                Never ( sinks ) into exploitation .     0.050
# 2209     1                        ( U ) nrelentingly stupid .    -0.800
#
# [2210 rows x 3 columns]

# %%
df_test['tb_label'] = pd.cut(df_test['tb_score'],bins=5,labels=[1,2,3,4,5])
df_test  = df_test.drop(['tb_score'],axis=1)

# %%
df_test
# Out:
#      label                                               text tb_label
# 0        3                     Effective but too-tepid biopic        4
# 1        4  If you sometimes like to go to the movies to h...        4
# 2        5  Emerges as something rare , an issue movie tha...        4
# 3        3  The film provides some great insight into the ...        4
# 4        5  Offers that rare combination of entertainment ...        3
# ...    ...                                                ...      ...
# 2205     4                   An imaginative comedy/thriller .        4
# 2206     5                      ( A ) rare , beautiful film .        4
# 2207     5                 ( An ) hilarious romantic comedy .        4
# 2208     4                Never ( sinks ) into exploitation .        3
# 2209     1                        ( U ) nrelentingly stupid .        1
#
# [2210 rows x 3 columns]

# %%
from sklearn.metrics import f1_score, accuracy_score

# %%
def f1_acc(df,pred_column):
    f1_macro  = f1_score(df['label'],df[pred_column],average='macro')
    acc = accuracy_score(df['label'],df[pred_column])
    print("F1 Score : {} \n Accuracy : {}".format(f1_macro,acc))

# %%
f1_acc(df_test,"tb_label")
# Out:
# F1 Score : 0.2468141571266554
#  Accuracy : 0.283710407239819

# %%
nltk.download('vader_lexicon')
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/mazeltan/nltk_data...
# True

# %%
vader = SentimentIntensityAnalyzer()

# %%
def vader_score(sent,vader):
    return vader.polarity_scores(sent)['compound']

# %%
df_test['vader_score'] =  df_test['text'].apply(lambda x : vader_score(x,vader))
df_test
# Out:
#      label                                               text tb_label  \
# 0        3                     Effective but too-tepid biopic        4
# 1        4  If you sometimes like to go to the movies to h...        4
# 2        5  Emerges as something rare , an issue movie tha...        4
# 3        3  The film provides some great insight into the ...        4
# 4        5  Offers that rare combination of entertainment ...        3
# ...    ...                                                ...      ...
# 2205     4                   An imaginative comedy/thriller .        4
# 2206     5                      ( A ) rare , beautiful film .        4
# 2207     5                 ( An ) hilarious romantic comedy .        4
# 2208     4                Never ( sinks ) into exploitation .        3
# 2209     1                        ( U ) nrelentingly stupid .        1
#
#       vader_score
# 0          0.2617
# 1          0.8271
# 2          0.6592
# 3          0.5994
# 4          0.4215
# ...           ...
# 2205       0.0000
# 2206       0.5994
# 2207       0.7845
# 2208       0.0000
# 2209      -0.5267
#
# [2210 rows x 4 columns]

# %%
df_test['vader_label'] = pd.cut(df_test['vader_score'],bins=5,labels=[1,2,3,4,5])
df_test = df_test.drop('vader_score',axis=1)
df_test
# Out:
#      label                                               text tb_label  \
# 0        3                     Effective but too-tepid biopic        4
# 1        4  If you sometimes like to go to the movies to h...        4
# 2        5  Emerges as something rare , an issue movie tha...        4
# 3        3  The film provides some great insight into the ...        4
# 4        5  Offers that rare combination of entertainment ...        3
# ...    ...                                                ...      ...
# 2205     4                   An imaginative comedy/thriller .        4
# 2206     5                      ( A ) rare , beautiful film .        4
# 2207     5                 ( An ) hilarious romantic comedy .        4
# 2208     4                Never ( sinks ) into exploitation .        3
# 2209     1                        ( U ) nrelentingly stupid .        1
#
#      vader_label
# 0              4
# 1              5
# 2              5
# 3              5
# 4              4
# ...          ...
# 2205           3
# 2206           5
# 2207           5
# 2208           3
# 2209           2
#
# [2210 rows x 4 columns]

# %%
f1_acc(df_test,"vader_label")
# Out:
# F1 Score : 0.3136923605939262
#  Accuracy : 0.3158371040723982
